# %%
# !ls data
# Out:
#  stats.txt	  't=28.0.tar.gz'  't=52.0.tar.gz'  't=77.0.tar.gz'
#  stats.txt.save   't=29.0.tar.gz'  't=53.0.tar.gz'  't=78.0.tar.gz'
# 't=0.0.tar'	  't=30.0.tar.gz'  't=54.0.tar.gz'  't=79.0.tar.gz'
# 't=0.0.tar.gz'	  't=3.0.tar.gz'   't=55.0.tar.gz'  't=80.0.tar.gz'
# 't=100.0.tar.gz'  't=31.0.tar.gz'  't=56.0.tar.gz'  't=8.0.tar.gz'
# 't=10.0.tar.gz'   't=32.0.tar.gz'  't=57.0.tar.gz'  't=81.0.tar.gz'
# 't=101.0.tar.gz'  't=33.0.tar.gz'  't=58.0.tar.gz'  't=82.0.tar.gz'
# 't=102.0.tar.gz'  't=34.0.tar.gz'  't=59.0.tar.gz'  't=83.0.tar.gz'
# 't=1.0.tar.gz'	  't=35.0.tar.gz'  't=60.0.tar.gz'  't=84.0.tar.gz'
# 't=11.0.tar.gz'   't=36.0.tar.gz'  't=6.0.tar.gz'   't=85.0.tar.gz'
# 't=12.0.tar.gz'   't=37.0.tar.gz'  't=61.0.tar.gz'  't=86.0.tar.gz'
# 't=13.0.tar.gz'   't=38.0.tar.gz'  't=62.0.tar.gz'  't=87.0.tar.gz'
# 't=14.0.tar.gz'   't=39.0.tar.gz'  't=63.0.tar.gz'  't=88.0.tar.gz'
# 't=15.0.tar.gz'   't=40.0.tar.gz'  't=64.0.tar.gz'  't=89.0.tar.gz'
# 't=16.0.tar.gz'   't=4.0.tar.gz'   't=65.0.tar.gz'  't=90.0.tar.gz'
# 't=17.0.tar.gz'   't=41.0.tar.gz'  't=66.0.tar.gz'  't=9.0.tar.gz'
# 't=18.0.tar.gz'   't=42.0.tar.gz'  't=67.0.tar.gz'  't=91.0.tar.gz'
# 't=19.0.tar.gz'   't=43.0.tar.gz'  't=68.0.tar.gz'  't=92.0.tar.gz'
# 't=20.0.tar.gz'   't=44.0.tar.gz'  't=69.0.tar.gz'  't=93.0.tar.gz'
# 't=2.0.tar.gz'	  't=45.0.tar.gz'  't=70.0.tar.gz'  't=94.0.tar.gz'
# 't=21.0.tar.gz'   't=46.0.tar.gz'  't=7.0.tar.gz'   't=95.0.tar.gz'
# 't=22.0.tar.gz'   't=47.0.tar.gz'  't=71.0.tar.gz'  't=96.0.tar.gz'
# 't=23.0.tar.gz'   't=48.0.tar.gz'  't=72.0.tar.gz'  't=97.0.tar.gz'
# 't=24.0.tar.gz'   't=49.0.tar.gz'  't=73.0.tar.gz'  't=98.0.tar.gz'
# 't=25.0.tar.gz'   't=50.0.tar.gz'  't=74.0.tar.gz'  't=99.0.tar.gz'
# 't=26.0.tar.gz'   't=5.0.tar.gz'   't=75.0.tar.gz'
# 't=27.0.tar.gz'   't=51.0.tar.gz'  't=76.0.tar.gz'

# %%
import fipy
import numpy as np
import matplotlib.pyplot as plt

aa = fipy.tools.dump.read('data/t=101.0.tar.gz')
aa
type(aa)
v = aa[0]
arr = v.value
arr_ = np.reshape(arr, (249, 249))
plt.imshow(arr_)

# %%
# viewer.plot()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from pathlib import Path
import fipy
from natsort import natsorted

# Directory path where your data files are located
directory_path = Path('/users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data')

# List to store frames of your animation
animation_frames = []

# Get the list of files in the directory and sort them naturally
sorted_files = natsorted(directory_path.iterdir())

# Iterate through each file in the sorted directory
for file_path in sorted_files:
    print(file_path)
    if file_path.is_file() and file_path.name.startswith('t') and file_path.name.endswith('.gz'):
        # Load data from the file using fipy.tools.dump.read (assuming it returns aa as you mentioned)
        aa = fipy.tools.dump.read(str(file_path))  # Convert Path object to string
        
        # Extract the first item (assuming it contains your variable 'v')
        v = aa[0]
        
        # Assuming arr is your data reshaped to (249, 249)
        arr = np.reshape(v.value, (249, 249))
        
        # Append the frame to the animation frames list
        animation_frames.append(arr)

# Create a figure and axis for the animation
fig, ax = plt.subplots(figsize=(10, 10))
im = ax.imshow(animation_frames[0], animated=True)

# Function to update the animation frames
def update(frame):
    im.set_array(frame)
    return im,

# Create the animation
ani = animation.FuncAnimation(fig, update, frames=animation_frames, interval=50, blit=True)

# Save the animation as an MP4 file
ani.save('animation.mp4', writer='ffmpeg', fps=20)

# plt.show()
# Out:
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/.ipynb_checkpoints
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/stats.txt
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/stats.txt.save
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=0.0.tar
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=0.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=1.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=2.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=3.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=4.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=5.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=6.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=7.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=8.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=9.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=10.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=11.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=12.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=13.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=14.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=15.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=16.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=17.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=18.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=19.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=20.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=21.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=22.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=23.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=24.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=25.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=26.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=27.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=28.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=29.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=30.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=31.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=32.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=33.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=34.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=35.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=36.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=37.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=38.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=39.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=40.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=41.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=42.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=43.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=44.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=45.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=46.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=47.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=48.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=49.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=50.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=51.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=52.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=53.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=54.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=55.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=56.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=57.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=58.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=59.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=60.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=61.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=62.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=63.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=64.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=65.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=66.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=67.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=68.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=69.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=70.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=71.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=72.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=73.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=74.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=75.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=76.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=77.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=78.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=79.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=80.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=81.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=82.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=83.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=84.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=85.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=86.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=87.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=88.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=89.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=90.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=91.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=92.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=93.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=94.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=95.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=96.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=97.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=98.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=99.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=100.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=101.0.tar.gz
# /users/aan2/Desktop/surf-2024-austyn-nguyen/benchmark8/data/t=102.0.tar.gz

# %%
# import yaml
 
# with open('params8a.yaml') as f:
#     dict = yaml.safe_load(f)
#     print(dict)

# %%
import os
import yaml
from rocrate.rocrate import ROCrate
from rocrate.model.contextentity import ContextEntity

# Create an empty ROCrate
crate = ROCrate()

# Add the YAML file to the crate
yaml_file_path = "params8a.yaml"
yaml_file = crate.add_file(yaml_file_path, properties={
    "name": "Parameter File",
    "encodingFormat": "text/yaml"
})

# Load the yaml file
with open(yaml_file_path, 'r') as file:
    yaml_content = yaml.safe_load(file)

# Loop through the YAML content and add it to the RO-Crate
for key, value in yaml_content.items():
    if value is not None:
        crate.add(ContextEntity(crate, identifier=f"#{key}", properties={
            "name": key,
            "value": value
        }))

# Write the crate metadata to a directory
crate.write("crate")

# Print the content of the RO-Crate metadata file
# !cat crate/ro-crate-metadata.json
# Out:
# {
#     "@context": "https://w3id.org/ro/crate/1.1/context",
#     "@graph": [
#         {
#             "@id": "./",
#             "@type": "Dataset",
#             "datePublished": "2024-07-08T16:34:07+00:00",
#             "hasPart": [
#                 {
#                     "@id": "params8a.yaml"
#                 }
#             ]
#         },
#         {
#             "@id": "ro-crate-metadata.json",
#             "@type": "CreativeWork",
#             "about": {
#                 "@id": "./"
#             },
#             "conformsTo": {
#                 "@id": "https://w3id.org/ro/crate/1.1"
#             }
#         },
#         {
#             "@id": "params8a.yaml",
#             "@type": "File",
#             "encodingFormat": "text/yaml",
#             "name": "Parameter File"
#         },
#         {
#             "@id": "#Lx",
#             "@type": "Thing",
#             "name": "Lx",
#             "value": 100.0
#         },
#         {
#             "@id": "#Ly",
#             "@type": "Thing",
#             "name": "Ly",
#             "value": 100.0
#         },
#         {
#             "@id": "#dx",
#             "@type": "Thing",
#             "name": "dx",
#             "value": 0.4
#         },
#         {
#             "@id": "#checkpoint_interval",
#             "@type": "Thing",
#             "name": "checkpoint_interval",
#             "value": 1.0
#         },
#         {
#             "@id": "#totaltime",
#             "@type": "Thing",
#             "name": "totaltime",
#             "value": 200.0
#         },
#         {
#             "@id": "#dt",
#             "@type": "Thing",
#             "name": "dt",
#             "value": 0.01
#         },
#         {
#             "@id": "#factor",
#             "@type": "Thing",
#             "name": "factor",
#             "value": 1.1
#         }
#     ]
# }
